# %% [markdown]
# **CLASSIFICAZIONE DI IMMAGINI CONTENTENTI DIGIT CON UNA CNN CUSTOM**

# %% [markdown]
# # Colab mounting

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import libraries 

import numpy as np
import keras
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
from keras.utils import img_to_array
from keras.utils import load_img
from keras.applications.vgg16 import preprocess_input

# %%
from keras.applications.vgg16 import VGG16
vgg_conv = VGG16(include_top = True, weights ='imagenet', input_shape=(224, 224, 3)) 
vgg_conv.summary()
# Out:
# ...
# 553467096/553467096 [==============================] - 24s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dfd7550d-662b-4e4e-a698-31d7d2236d6b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dfd7550d-662b-4e4e-a698-31d7d2236d6b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img_to_predict=load_img('GATTO.jpeg')
imgs_to_pred_arr = img_to_array(img_to_predict)
print(imgs_to_pred_arr.shape)
# Out:
# (863, 1440, 3)

# %%
#print VGG16 layers shape

for layer in vgg_conv.layers:
    print(layer.output_shape)
# Out:
# [(None, 224, 224, 3)]
# (None, 224, 224, 64)
# (None, 224, 224, 64)
# (None, 112, 112, 64)
# (None, 112, 112, 128)
# (None, 112, 112, 128)
# (None, 56, 56, 128)
# (None, 56, 56, 256)
# (None, 56, 56, 256)
# (None, 56, 56, 256)
# (None, 28, 28, 256)
# (None, 28, 28, 512)
# (None, 28, 28, 512)
# (None, 28, 28, 512)
# (None, 14, 14, 512)
# (None, 14, 14, 512)
# (None, 14, 14, 512)
# (None, 14, 14, 512)
# (None, 7, 7, 512)
# (None, 25088)
# (None, 4096)
# (None, 4096)
# (None, 1000)

# %%
imgs_to_pred_arr=np.expand_dims(imgs_to_pred_arr, 0)
print(imgs_to_pred_arr.shape)
# Out:
# (1, 863, 1440, 3)

# %%
predictions=vgg_conv.predict(imgs_to_pred_arr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-6533e404adee> in <module>
# ----> 1 predictions=vgg_conv.predict(imgs_to_pred_arr)
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in tf__predict_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
# ...

# %%
#first way 
from PIL import Image
img_to_predict2=load_img('GATTO.jpeg')
img_arr2=img_to_array(img_to_predict2) 
print("shape before resizing", img_arr2.shape)

img = img_to_predict2.resize((224,224))
img_arr=img_to_array(img) 
print("shape after resizing", img_arr.shape)
print(img_arr.max())

img_arr=preprocess_input(img_arr)
print(img_arr.max())
# Out:
# shape before resizing (863, 1440, 3)
# shape after resizing (224, 224, 3)
# 255.0
# 151.061

# %%
#second way to resize image dimensions and performing preprocessing according to VGG16  

# img_to_predict=load_img('GATTO.jpeg', target_size=(224,224))
# imgs_to_pred_arr = img_to_array(img_to_predict)
# imgs_to_pred_arr=preprocess_input(imgs_to_pred_arr) 
# print(imgs_to_pred_arr.max())
# imgs_to_pred_arr.shape

# %%
imgs_to_pred_arr=np.expand_dims(img_arr, 0)

# %%
predictions=vgg_conv.predict(imgs_to_pred_arr)
print(predictions)
# Out:
# 1/1 [==============================] - 9s 9s/step
# [[2.32015263e-05 2.35432890e-05 1.01437373e-03 2.17845547e-03
#   5.16411033e-04 7.16721333e-05 1.01248770e-04 8.18640037e-05
#   9.58871096e-05 2.90270345e-05 9.24871892e-06 1.47364563e-05
#   4.16044531e-05 1.03861763e-04 4.10496341e-06 4.77120047e-05
#   9.10744566e-05 2.02389128e-04 6.17144833e-05 3.97811054e-05
#   3.13860946e-05 3.93995288e-04 2.43640839e-04 8.50622819e-05
#   5.83626563e-04 1.13668248e-05 2.26549000e-05 2.26064058e-05
#   1.98938633e-05 1.24740953e-04 1.82649692e-05 1.02560543e-05
#   7.98152087e-06 2.17960460e-05 2.36609194e-05 1.19589877e-05
#   2.13874191e-05 1.78268274e-05 1.01175989e-04 3.31864794e-05
#   1.05404426e-04 4.93492516e-05 1.01360256e-05 1.94166096e-05
#   3.87481181e-04 9.29812086e-06 1.68581479e-04 1.98166654e-05
#   7.49933952e-06 1.71708907e-05 7.57743474e-05 1.10194211e-04
#   1.69743813e-04 3.82697435e-05 1.27543855e-04 7.39119350e-05
# ...

# %%
from keras.applications.imagenet_utils import decode_predictions
label_vgg = decode_predictions(predictions)
# Out:
# ...
# 35363/35363 [==============================] - 0s 0us/step

# %%
label_vgg
# Out:
# [[('n02127052', 'lynx', 0.13088265),
#   ('n02123045', 'tabby', 0.10537916),
#   ('n02124075', 'Egyptian_cat', 0.0632597),
#   ('n03958227', 'plastic_bag', 0.06259612),
#   ('n02109961', 'Eskimo_dog', 0.059558474)]]

# %%
label_vgg[0][0][:]
